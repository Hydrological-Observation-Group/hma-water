# %% [markdown]
# ### download dahiti lake height in the hma

# %%
import os
import json 
import requests
import pprint

# %% [markdown]
# #### hma region: 26-45, 66-106

# %%
dahiti_key = '5C5F7D96A01C2A3C2D0F11636BF2F96C1113A22989086EEDCBC1E02710E7474D'
dir_download = 'data/water-height/dahiti'
region = [25, 45, 100, 106]  ## search region, [min_lat, max_lat, min_lon, max_lon]

# %% [markdown]
# #### download

# %%
''' Download path were all water level time series will be stored '''
if not os.path.isdir(dir_download):
	os.mkdir(dir_download)
API_KEY = dahiti_key
OUTPUT_FORMAT = 'netcdf' ## Option: ascci, json, netcdf, csv 

url = 'https://dahiti.dgfi.tum.de/api/v2/list-targets/'
args = {}
''' User configuration '''
args['api_key'] = API_KEY
''' Search options '''
# args['basin'] = 'Amazon'
# args['continent'] = 'Asia'
#args['country'] = 'de'
args['min_lon'], args['max_lon'] = region[2], region[3]   #### 66-106
args['min_lat'], args['max_lat'] = region[0], region[1]    #### 26-45

# %%
''' send request as method POST '''
response = requests.post(url, data=args)
if response.status_code == 200:
	''' convert json string in python list '''
	targets = json.loads(response.text)['data']
	print ('Dataset(s) found:',len(targets))		
	for target in targets:
		print (target)		
		path_target_file = dir_download + '/' + str(target['dahiti_id']) + '.nc'
		if os.path.exists(path_target_file):
			print(f"File {target['dahiti_id']} already exists. Skipping download.")
			continue

		''' download water level time series '''
		url = 'https://dahiti.dgfi.tum.de/api/v2/download-water-level/'
		args = {}
		args['api_key'] = API_KEY
		args['dahiti_id'] = target['dahiti_id']
		args['format'] = OUTPUT_FORMAT		
		path_output = os.path.abspath(dir_download+'/'+str(target['dahiti_id'])+'.nc')
		print ('Downloading ... ',target['dahiti_id'],'->',target['target_name'].encode("utf8"),'('+path_output+')')		
		response_download = requests.post(url, json=args)
		if response_download.status_code == 200:
			with open(path_output, 'wb') as f:
				for chunk in response_download.iter_content(chunk_size=1024): 
					if chunk:
						f.write(chunk)
		else:
			print ('Error: `download-water-level` request failed!')
			data = json.loads(response_download.text)
			pprint.pprint(data)
			# sys.exit(0)
else:
	print ('Error: `list-targets` request failed!')
	data = json.loads(response.text)
	pprint.pprint(data)
# Out:
# Dataset(s) found: 36
# {'dahiti_id': 24995, 'target_name': 'Bai-long-jiang, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 105.6699, 'latitude': 32.3878, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  24995 -> b'Bai-long-jiang, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/24995.nc)
# {'dahiti_id': 19038, 'target_name': 'Chang-jiang, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 105.1318, 'latitude': 28.7061, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  19038 -> b'Chang-jiang, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/19038.nc)
# {'dahiti_id': 20117, 'target_name': 'Chang-jiang, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 101.4872, 'latitude': 26.5724, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  20117 -> b'Chang-jiang, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/20117.nc)
# {'dahiti_id': 25023, 'target_name': 'Dadu, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 103.5992, 'latitude': 29.1925, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 25023 already exists. Skipping download.
# {'dahiti_id': 25028, 'target_name': 'Fu, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 105.2806, 'latitude': 30.9983, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 25028 already exists. Skipping download.
# {'dahiti_id': 25027, 'target_name': 'Fu, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 105.5669, 'latitude': 30.5529, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 25027 already exists. Skipping download.
# {'dahiti_id': 25117, 'target_name': 'Huang-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 105.4041, 'latitude': 37.4983, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25117 -> b'Huang-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25117.nc)
# {'dahiti_id': 25120, 'target_name': 'Huang-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 104.5357, 'latitude': 36.4735, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25120 -> b'Huang-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25120.nc)
# {'dahiti_id': 25124, 'target_name': 'Huang-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 100.3263, 'latitude': 35.7632, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25124 -> b'Huang-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25124.nc)
# {'dahiti_id': 25130, 'target_name': 'Huang-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 100.0208, 'latitude': 33.6358, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25130 -> b'Huang-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25130.nc)
# {'dahiti_id': 25129, 'target_name': 'Huang-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 101.9462, 'latitude': 33.4441, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25129 -> b'Huang-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25129.nc)
# {'dahiti_id': 25128, 'target_name': 'Huang-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 102.2039, 'latitude': 33.3499, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25128 -> b'Huang-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25128.nc)
# {'dahiti_id': 25125, 'target_name': 'Huang-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 101.5174, 'latitude': 34.2049, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25125 -> b'Huang-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25125.nc)
# {'dahiti_id': 25127, 'target_name': 'Huang-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 102.4165, 'latitude': 33.4337, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25127 -> b'Huang-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25127.nc)
# {'dahiti_id': 25126, 'target_name': 'Huang-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 101.7662, 'latitude': 34.0629, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25126 -> b'Huang-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25126.nc)
# {'dahiti_id': 41703, 'target_name': 'Longyangxia, Lake', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 100.7278, 'latitude': 36.0267, 'type': 'Lake', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 41703 already exists. Skipping download.
# {'dahiti_id': 227, 'target_name': 'Qinghai, Lake', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 100.264, 'latitude': 36.9001, 'type': 'Lake', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 227 already exists. Skipping download.
# {'dahiti_id': 19043, 'target_name': 'San-cha-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 105.7415, 'latitude': 26.3911, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  19043 -> b'San-cha-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/19043.nc)
# {'dahiti_id': 25146, 'target_name': 'Tao-he, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 103.429, 'latitude': 35.9091, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25146 -> b'Tao-he, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25146.nc)
# {'dahiti_id': 16627, 'target_name': 'Unnamed, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 101.9604, 'latitude': 27.3598, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  16627 -> b'Unnamed, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/16627.nc)
# {'dahiti_id': 16304, 'target_name': 'Unnamed, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 102.3727, 'latitude': 33.6026, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  16304 -> b'Unnamed, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/16304.nc)
# {'dahiti_id': 16303, 'target_name': 'Unnamed, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 102.3337, 'latitude': 33.7373, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  16303 -> b'Unnamed, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/16303.nc)
# {'dahiti_id': 14640, 'target_name': 'Unnamed, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 102.3122, 'latitude': 33.7189, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  14640 -> b'Unnamed, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/14640.nc)
# {'dahiti_id': 25070, 'target_name': 'Ya Long, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 101.8144, 'latitude': 26.7932, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# Downloading ...  25070 -> b'Ya Long, River' (/home/xin/Developer-luo/hma-water/data/water-height/dahiti/25070.nc)
# {'dahiti_id': 25008, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 100.4109, 'latitude': 26.7985, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 25008 already exists. Skipping download.
# {'dahiti_id': 25010, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 100.0025, 'latitude': 26.8872, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 25010 already exists. Skipping download.
# {'dahiti_id': 25009, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 100.5299, 'latitude': 27.2555, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 25009 already exists. Skipping download.
# {'dahiti_id': 25006, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 102.0973, 'latitude': 26.0216, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 25006 already exists. Skipping download.
# {'dahiti_id': 25005, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 102.609, 'latitude': 26.25, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 25005 already exists. Skipping download.
# {'dahiti_id': 25004, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 104.6723, 'latitude': 28.7657, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 25004 already exists. Skipping download.
# {'dahiti_id': 25003, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 105.9718, 'latitude': 29.0619, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 25003 already exists. Skipping download.
# {'dahiti_id': 17055, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 105.5529, 'latitude': 28.897, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 17055 already exists. Skipping download.
# {'dahiti_id': 16675, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 104.6523, 'latitude': 28.7689, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 16675 already exists. Skipping download.
# {'dahiti_id': 15224, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 105.1269, 'latitude': 28.706, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 15224 already exists. Skipping download.
# {'dahiti_id': 13807, 'target_name': 'Yangtze, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 105.6374, 'latitude': 28.8691, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 13807 already exists. Skipping download.
# {'dahiti_id': 18127, 'target_name': 'Yellow, River', 'location': None, 'continent': 'Asia', 'country': 'China', 'longitude': 101.9258, 'latitude': 33.9982, 'type': 'River', 'data_access': {'water_level_altimetry': 'public', 'surface_area': None, 'water_occurrence_mask': None, 'land_water_mask': None, 'volume_variation': None, 'hypsometry': None, 'bathymetry': None, 'water_level_hypsometry': None, 'discharge': None, 'water_surface_slope': None}}
# File 18127 already exists. Skipping download.
