# %% [markdown]
# ### Create in-situ station location file.

# %%
import os
import geopandas as gpd
from shapely.geometry import Point

# %% [markdown]
# #### data source: data/validation/lake-height

# %%
lake_name = ['Zhari Namco',  'DawaCo', 'DazegCo', 'BamCo', 'PengCo',
              'NamCo', 'SilingCo', 'MemarCo', 'Luotuo lake', 'LumajiangdongCo',
              'Jieze Caka', 'Kalakuli']
lake_coords = [(85.61, 30.93), (84.96, 31.24), (87.53, 31.89), (90.58, 31.26), (90.97, 31.50),
               (90.60, 30.74), (88.63, 30.95), (82.31, 34.22), (81.86, 34.46), (81.61, 34.02),
               (80.90, 33.95), (75.03, 38.43)]
lake_gdf = gpd.GeoDataFrame({'lake_name': lake_name},
                            geometry=[Point(xy) for xy in lake_coords],
                            crs="EPSG:4326")
lake_gdf
# Out:
#           lake_name             geometry
# 0       Zhari Namco  POINT (85.61 30.93)
# 1            DawaCo  POINT (84.96 31.24)
# 2           DazegCo  POINT (87.53 31.89)
# 3             BamCo  POINT (90.58 31.26)
# 4            PengCo   POINT (90.97 31.5)
# 5             NamCo   POINT (90.6 30.74)
# 6          SilingCo  POINT (88.63 30.95)
# 7           MemarCo  POINT (82.31 34.22)
# 8       Luotuo lake  POINT (81.86 34.46)
# 9   LumajiangdongCo  POINT (81.61 34.02)
# 10       Jieze Caka   POINT (80.9 33.95)
# 11         Kalakuli  POINT (75.03 38.43)

# %%
# path_save = 'data/validation/lake-station/lake_station.gpkg'
# if os.path.exists(path_save): os.remove(path_save) 
# lake_gdf.to_file(path_save, driver='GPKG')
